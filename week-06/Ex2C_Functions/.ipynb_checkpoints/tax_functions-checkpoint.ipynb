# %% [markdown]
# # Exercise 2.C Lab 3
# Tax Calculation Functions

# %% [markdown]
# Function 1

# %%
def get_soc_sec_tax(gross_pay):
    return gross_pay * 0.062

# %% [markdown]
# Function 2

# %%
def get_medicare_tax(gross_pay):
    return gross_pay * 0.0145

# %% [markdown]
# Function 3

# %%
def get_federal_tax(gross_pay, withholding_code):
    if withholding_code == 0:
        rate = 0.23
    elif withholding_code == 1:
        rate = 0.21
    elif withholding_code == 2:
        rate = 0.195
    elif withholding_code == 3:
        rate = 0.185
    else:
        # withholding_code is 4 or more
        rate = 0.18 - (withholding_code - 4) * 0.005
    
    return gross_pay * rate

# %%
gross1 = 750
code1 = 0

print(f"Person 1 - Gross Pay: ${gross1}, Withholding Code: {code1}")
print(f"Social Security Tax: ${get_soc_sec_tax(gross1):.2f}")
print(f"Medicare Tax: ${get_medicare_tax(gross1):.2f}")
print(f"Federal Tax: ${get_federal_tax(gross1, code1):.2f}")
# Out:
# Person 1 - Gross Pay: $750, Withholding Code: 0
# Social Security Tax: $46.50
# Medicare Tax: $10.88
# Federal Tax: $172.50

# %%
gross1 = 1550
code1 = 2

print(f"Person 2 - Gross Pay: ${gross1}, Withholding Code: {code1}")
print(f"Social Security Tax: ${get_soc_sec_tax(gross1):.2f}")
print(f"Medicare Tax: ${get_medicare_tax(gross1):.2f}")
print(f"Federal Tax: ${get_federal_tax(gross1, code1):.2f}")
# Out:
# Person 2 - Gross Pay: $1550, Withholding Code: 2
# Social Security Tax: $96.10
# Medicare Tax: $22.48
# Federal Tax: $302.25

# %%
gross1 = 1100
code1 = 5

print(f"Person 3 - Gross Pay: ${gross1}, Withholding Code: {code1}")
print(f"Social Security Tax: ${get_soc_sec_tax(gross1):.2f}")
print(f"Medicare Tax: ${get_medicare_tax(gross1):.2f}")
print(f"Federal Tax: ${get_federal_tax(gross1, code1):.2f}")
# Out:
# Person 3 - Gross Pay: $1100, Withholding Code: 5
# Social Security Tax: $68.20
# Medicare Tax: $15.95
# Federal Tax: $192.50
